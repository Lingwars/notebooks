# %% [markdown]
# # Scraping

# %% [markdown]
# El *scraping* es el arte de descargarse el contenido de una web a partir del HTML de la página. Como todos sabemos es mucho más fácil acceder a los datos de un sitio si dispone de una API, nos permite enganchar nuestro programa directamente y podemos obtener información actualizada en tiempo real; pero muchas veces la realidad no es tan sencilla y sólo disponemos de los datos a través de la interfaz que vemos en el navegador.
#
# Debajo de ese conjunto de textos con colores, tipografías, imagénes y trucos para embelesar al usuario, lo que se esconden es un lenguaje de marcado que se llama HTML (*Hypertext markup language*) que tiene un aspecto parecido a este:

# %% [markdown]
# ```html
# <html>
#     <head>
#         <!-- Comentario: Este título se mostrará en la barra superior del navegador -->
#         <title>Wikipedia | HTML</title>
#     </head>
#     <body>
#         <!-- Todo lo incluido dentro de la etiqueta 'body' es lo vemos en el navegador -->
#         <div id="content">
#             <h1>Ejemplo de HTML</h1>
#             <div class="section">
#                 <h2>Primera sección</h2>
#                 <p>Y esto es un párrafo con algo en <strong>negrita</strong> y poco más.</p>
#             </div>
#             <div>
#                 <h2>Segunda sección</h2>
#                 <p>En este otro párrafo pongo un <a href="https://lingwars.github.io/blog">link a Lingwars</a>.</p>
#             </div>
#         </div>
#     </body>
# </html>
# ```

# %% [markdown]
# A través de expresiones regulares y cadenas XPath podemos acceder directamente a los contenidos que nos interesan dentro de esta estructura jerárquica. Los ordenadores son muy buenos haciendo estas tareas, sólo tenemos que decirles dónde buscar.

# %% [markdown]
# **Nota.-** Este cuaderno es una extensión del artículo publicado en el blog de Lingẅars [Scrapeando la web con Python](http://lingwars.github.io/blog/scrape-xpath.html), puedes acudir allí para tener más detalles, aquí nos centraremos más en el código.

# %% [markdown]
# ## 1. Descargarse el contenido de la web

# %% [markdown]
# El primer paso, en cualquier proceso de scraping es descargarse el contenido de la web que nos interesa, por ejemplo:
# ```
# http://www.elmundo.es/internacional.html
# ```

# %%
import requests

url = "http://www.elmundo.es/internacional.html"

def download(url):
    r = requests.get(url)
    if r.status_code != 200:
        print("! Error {} retrieving url {}".format(r.status_code, url))
    return r

page = download(url)

print("A continuación una muestra del HTML que nos hemos descargado (sólo los primeros 150 caracteres):")
print(page.text[:150])
# Out:
# A continuación una muestra del HTML que nos hemos descargado (sólo los primeros 150 caracteres):
# <!DOCTYPE html>
# <html lang="es">
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=iso-8859-15"/>
# <meta http-equiv="X-UA-Compatible"

# %% [markdown]
# Si abres la URL anterior en tu navegador [http://www.elmundo.es/internacional.html](http://www.elmundo.es/internacional.html) y le das a "ver código fuente" (click con el botón derecho del ratón > ver código fuente/inspeccionar elemento) podrás comprobar que el HTML anterior se corresponde con el de la web de El País. Perfecto, ya tenemos el contenido sobre el que vamos a trabajar.

# %% [markdown]
# ## 2. Accediendo a los datos que nos interesan: XPath

# %% [markdown]
# Lo siguiente que tenemos que hacer es recuperar los datos que nos interesan. Para ello es extremadamente útil conocer el funcionamiento de XPath y sus posibilidades. ¿Vinistéis al taller que hicimos de scraping? ¡No? Bueno... menos mal que el XPath no nos lo hemos inventado nosotros sino que podéis encontrar muchísima información online.

# %% [markdown]
# Nosotros lo que vamos a hacer ahora es recuperar todos los enlaces que hay en el HTML anterior (la portada de internacional de El Mundo), sin duda, entre estos enlaces estarán las noticias de actualidad más importantes, ¡es la portada!
#
# Si te fijas en el HTML podrás comprobar que los enlaces tienen una estructura como la siguiente:
#
# ```html
# <a href="https://lingwars.github.io/blog">link a Lingwars</a>
# ```
#
# Es decir, siempre aparecen en un nodo `a` con un atributo `href` que es la dirección a la que apuntan y un texto dentro del nodo que es el que se muestra al usuario (convencionalmente, se muestra subrayado y en azul).
#
# Para recuperar todos los enlaces podemos, por lo tanto, utilizar una cadena xpath como la siguiente:
#
# ```xpath
# //a/@href
# ```
#
# Vamos a probarlo de verdad:

# %%
from lxml import html

xpath_string = '//a/@href'

# Necesito cargar mi html en una estructura de árbol XML
tree = html.fromstring(page.content)
# Hago la llamada al xpath para obtener los resultados
results = tree.xpath(xpath_string)

print("Hay {} enlaces en esta web!".format(len(results)))
for u in results[:20]:  # Voy a mostrar sólo los 20 primeros
    print(u)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-ebcb2388147f> in <module>()
# ----> 1 from lxml import html
#       2
#       3 xpath_string = '//a/@href'
#       4
#       5 # Necesito cargar mi html en una estructura de árbol XML
#
# ImportError: No module named 'lxml'

# %% [markdown]
# ## 3. Filtrar, eliminar duplicados,...

# %% [markdown]
# ### regex
# En la muestra anterior podemos ver que hay algunos enlaces que no se corresponden con noticias, o que abandonan la sección de internacional que es la que nos interesaba,... tenemos que intentar reconocer cuál es el patrón que comparten todos los enlaces que nos interesan.
#
# Una vez que lo hayamos identificado, podemos construir una expresión **regex** (o varias) que los identifiquen. Sugerencia de la casa:
#
# ```
# article_internacional_patterns = [
#     re.compile('https?:\/\/(www.)?elmundo.es\/internacional\/(?P<year>\d{4})\/(?P<month>\d{2})\/(?P<day>\d{2})\/(?P<uuid>[\d\w]+).html'),
#     ]
# ```
#
# Y con este patrón podemos filtrar todas las URLs anteriores para quedarnos sólo con las que sean *internacional*.

# %%
import re

pattern = re.compile('https?:\/\/(www.)?elmundo.es\/internacional\/(?P<year>\d{4})\/(?P<month>\d{2})\/(?P<day>\d{2})\/(?P<uuid>[\d\w]+).html')

results = filter(lambda u: pattern.match(u), results)
results = list(results)

print("He encontrado {} URL que encajen en el patrón anterior (muestro sólo 20):".format(len(results)))
for u in results[:20]:
    print(u)
# Out:
# He encontrado 145 URL que encajen en el patrón anterior (muestro sólo 20):
# http://www.elmundo.es/internacional/2016/07/15/578940e3268e3e1b0b8b45fb.html
# http://www.elmundo.es/internacional/2016/07/15/578940e3268e3e1b0b8b45fb.html
# http://www.elmundo.es/internacional/2016/07/15/578940e3268e3e1b0b8b45fb.html#comentarios
# http://www.elmundo.es/internacional/2016/07/16/57898a68e5fdea87598b468d.html
# http://www.elmundo.es/internacional/2016/07/16/5789fba1468aebba388b4620.html
# http://www.elmundo.es/internacional/2016/07/16/5789fba1468aebba388b4620.html
# http://www.elmundo.es/internacional/2016/07/16/5789fba1468aebba388b4620.html
# http://www.elmundo.es/internacional/2016/07/16/5789e5b546163f54368b464b.html
# http://www.elmundo.es/internacional/2016/07/16/5789e5b546163f54368b464b.html
# http://www.elmundo.es/internacional/2016/07/16/5789e5b546163f54368b464b.html#comentarios
# http://www.elmundo.es/internacional/2016/07/16/578932ba268e3ed26b8b46aa.html
# http://www.elmundo.es/internacional/2016/07/16/578932ba268e3ed26b8b46aa.html
# http://www.elmundo.es/internacional/2016/07/16/578932ba268e3ed26b8b46aa.html#comentarios
# http://www.elmundo.es/internacional/2016/07/15/5788defa46163f617e8b457d.html
# http://www.elmundo.es/internacional/2016/07/15/5788defa46163f617e8b457d.html
# http://www.elmundo.es/internacional/2016/07/15/5788defa46163f617e8b457d.html#comentarios
# http://www.elmundo.es/internacional/2016/07/16/578912c922601df5248b4689.html
# http://www.elmundo.es/internacional/2016/07/16/578912c922601df5248b4689.html
# http://www.elmundo.es/internacional/2016/07/16/578912c922601df5248b4689.html#comentarios
# http://www.elmundo.es/internacional/2016/07/15/578823f9268e3eca6b8b45ce.html

# %% [markdown]
# ### Eliminar duplicados
# Pero puede haber duplicados, vamos a librarnos de ellos con el siguiente código:

# %%
articles = set()  # Los contenedores de tipo set no permiten elementos repetidos ;D
for r in results:
    r = r.rsplit("#", 1)[0]
    r = r.rsplit("?", 1)[0]
    articles.add(r)

# %% [markdown]
# ¿Cuántos articulos crees que nos han quedado? Vamos a verlo

# %%
print("He encontrado {} URL que encajen en el patrón anterior:".format(len(articles)))
for u in articles:
    print(u)
# Out:
# He encontrado 57 URL que encajen en el patrón anterior:
# http://www.elmundo.es/internacional/2016/07/13/5786a3a8e2704ebe158b4581.html
# http://www.elmundo.es/internacional/2016/07/13/57869f66468aebb6358b45fd.html
# http://www.elmundo.es/internacional/2016/07/16/57898a68e5fdea87598b468d.html
# http://www.elmundo.es/internacional/2016/07/15/57892f1146163f6f7b8b459c.html
# http://www.elmundo.es/internacional/2016/07/16/578994dbe5fdea1a788b45fd.html
# http://www.elmundo.es/internacional/2016/07/15/57889ec6e2704e59178b4597.html
# http://www.elmundo.es/internacional/2016/07/16/578932ba268e3ed26b8b46aa.html
# http://www.elmundo.es/internacional/2016/07/13/57862ab146163fe97a8b4645.html
# http://www.elmundo.es/internacional/2016/07/13/578649f422601d2e4c8b45a0.html
# http://www.elmundo.es/internacional/2016/07/15/57889f8746163f54368b45b3.html
# http://www.elmundo.es/internacional/2016/07/15/5788a7e4e2704e6b588b45ac.html
# http://www.elmundo.es/internacional/2016/07/15/5787e64b46163f97198b4646.html
# http://www.elmundo.es/internacional/2016/07/15/57882a94268e3ed16b8b45cb.html
# http://www.elmundo.es/internacional/2016/07/14/57875f21e5fdea58738b459c.html
# http://www.elmundo.es/internacional/2016/07/14/57865df622601dc5078b4634.html
# http://www.elmundo.es/internacional/2016/07/13/5786379b46163fe97a8b4653.html
# http://www.elmundo.es/internacional/2016/07/13/57867e2b22601d0c448b4618.html
# http://www.elmundo.es/internacional/2016/07/15/57887fcb468aebc1318b466e.html
# http://www.elmundo.es/internacional/2016/07/14/57872bf6e2704e9c2b8b456d.html
# http://www.elmundo.es/internacional/2016/07/14/57868781ca4741d3318b461c.html
# http://www.elmundo.es/internacional/2016/07/13/5786359be5fdeac9068b45df.html
# http://www.elmundo.es/internacional/2016/07/15/578823f9268e3eca6b8b45ce.html
# http://www.elmundo.es/internacional/2016/07/14/5787adf1ca4741b7718b4592.html
# http://www.elmundo.es/internacional/2016/07/15/5787d44b46163f2a358b4601.html
# http://www.elmundo.es/internacional/2016/07/14/5787a40846163f38758b464f.html
# http://www.elmundo.es/internacional/2016/07/16/5789e5b546163f54368b464b.html
# http://www.elmundo.es/internacional/2016/07/13/578664e1ca474124288b45fc.html
# http://www.elmundo.es/internacional/2016/07/13/5786756546163fd5588b4573.html
# http://www.elmundo.es/internacional/2016/07/14/5787e1bf468aeb12138b46a1.html
# http://www.elmundo.es/internacional/2016/07/15/57891024268e3ee26b8b4680.html
# http://www.elmundo.es/internacional/2016/07/16/5789ed2246163f43018b45d9.html
# http://www.elmundo.es/internacional/2016/07/14/57880490e2704ebe158b4641.html
# http://www.elmundo.es/internacional/2016/07/15/5788c428e2704e32738b4612.html
# http://www.elmundo.es/internacional/2016/07/13/57863b14e2704ee3418b45f3.html
# http://www.elmundo.es/internacional/2016/07/14/5787763de5fdea1f198b4616.html
# http://www.elmundo.es/internacional/2016/07/13/5786500b46163f45198b45cd.html
# http://www.elmundo.es/internacional/2016/07/13/57863b3ce5fdea8e2a8b45c8.html
# http://www.elmundo.es/internacional/2016/07/16/5789fba1468aebba388b4620.html
# http://www.elmundo.es/internacional/2016/07/13/57865636268e3e43418b4651.html
# http://www.elmundo.es/internacional/2016/07/15/5788f55846163f947c8b457e.html
# http://www.elmundo.es/internacional/2016/07/15/578903dee2704e17078b4641.html
# http://www.elmundo.es/internacional/2016/07/16/5789dd23468aeb592b8b4641.html
# http://www.elmundo.es/internacional/2016/07/16/57890b5122601d865d8b45f8.html
# http://www.elmundo.es/internacional/2016/07/14/5787428d46163f72208b459d.html
# http://www.elmundo.es/internacional/2016/07/15/57881a72268e3ed06b8b45c6.html
# http://www.elmundo.es/internacional/2016/07/15/5788d76f468aeb93178b45da.html
# http://www.elmundo.es/internacional/2016/07/13/5786829046163fef4a8b456c.html
# http://www.elmundo.es/internacional/2016/07/16/578912c922601df5248b4689.html
# http://www.elmundo.es/internacional/2016/07/13/5786280fca4741a3508b4637.html
# http://www.elmundo.es/internacional/2016/07/15/5788defa46163f617e8b457d.html
# http://www.elmundo.es/internacional/2016/07/15/5788d88ae2704e14198b4612.html
# http://www.elmundo.es/internacional/2016/07/13/578682bd22601df07b8b45d9.html
# http://www.elmundo.es/internacional/2016/07/14/57873a44e5fdeac82e8b45bc.html
# http://www.elmundo.es/internacional/2016/07/15/578817d1268e3ec66b8b45d3.html
# http://www.elmundo.es/internacional/2016/07/15/578940e3268e3e1b0b8b45fb.html
# http://www.elmundo.es/internacional/2016/07/14/5786c4ef22601d986b8b4570.html
# http://www.elmundo.es/internacional/2016/07/14/578714cf46163fee638b459f.html

# %% [markdown]
# Hemos conseguido los enlaces a todas las noticias que hay en la portada de la sección internacional de El Mundo.

# %% [markdown]
# ## 4. Navegar por los enlaces
# Pero somos ambiciosos y realmente lo que queríamos era obtener los titulares y el texto de cada uno de los artículos. ¿Puedo hacerlo con Python? ¡Cómo no, pues claro!
#
# Fíjate que ahora tenemos una lista de URLs que apuntan a todas las noticias que estaban en portada de la sección internacional y, por si te has olvidado, te recuerdo que este cuaderno empezó con una URL... Básicamente podemos realizar el proceso que hemos seguido desde el principio para cada una de estas URLs y, utilizando los XPath adecuados, obtendremos toda la información de estas noticias.
#
# Vamos a definir unas cuantas variables útiles y luego iremos a por el código. Si analizamos el HTML de cualquier noticia de las anteriores, podemos construir algunos XPath que nos permitirán recuperar alguna información relevante:

# %%
xpath_string = {'title': "//article/h1[@itemprop='headline']/text()",
                'summary': "//article/div[@itemprop='articleBody']/p[@class='summary-lead']//text()",
                'author': "//footer/ul/li[@itemprop='name']//text()",
                'location': "//footer/ul/li[@itemprop='address']//text()",
                'datetime': "//article/div[@itemprop='articleBody']/time//text()",
                'content': "//article/div[@itemprop='articleBody']/p[not(@class='summary-lead')]//text()",
                 }

# %% [markdown]
# Pues hagamos un bucle que recorra todos los enlaces que teníamos guardados en la variable `articles` y vaya ejecutando estos xpaths para obtener la información

# %%
for i, article in enumerate(articles):
    print("Article #{}".format(i))
    print(" - url: {}".format(article))
    data = download(article)
    tree = html.fromstring(data.content)
    
    for key, value in xpath_string.items():
        item = tree.xpath(value)
        if not isinstance(item, str):
            if key == 'summary':
                item = '. '.join(item).strip()
            else:
                item = ''.join(item).strip()
        print(" - {}: {}".format(key, item[:60]))
# Out:
# Article #0
#  - url: http://www.elmundo.es/internacional/2016/07/13/5786a3a8e2704ebe158b4581.html
#  - datetime: 13/07/2016 22:51
#  - content: "La Organización de Estados Americanos (OEA) nos ha decepcio
#  - location:
#  - title: "La OEA nos ha decepcionado al no ser capaz de construir uni
#  - summary: Queremos convertir Bolivia en el centro energético de Améric
#  - author: ROCÍO GALVÁN
# Article #1
#  - url: http://www.elmundo.es/internacional/2016/07/13/57869f66468aebb6358b45fd.html
#  - datetime: 13/07/2016 22:22
#  - content: Theresa May entró este miércoles en el número 10 de Downing
#  - location: Londres
#  - title: Theresa May reta a Europa
#  - summary: La primera ministra británica coloca al eurófobo Boris Johns
#  - author: CARLOS FRESNEDA
# Article #2
#  - url: http://www.elmundo.es/internacional/2016/07/16/57898a68e5fdea87598b468d.html
#  - datetime: 16/07/2016 03:25
#  - content: El presidente del Gobierno, Mariano Rajoy, ha trasladado a T
#  - location:
#  - title: Rajoy: "España apoya el orden constitucional democrático en
#  - summary: El Servicio de Inteligencia de Turquía da por fracasado el G
#  - author: AGENCIAS
# Article #3
#  - url: http://www.elmundo.es/internacional/2016/07/15/57892f1146163f6f7b8b459c.html
#  - datetime: 15/07/2016 20:49
#  - content: El virtual candidato republicano a la presidencia de los Est
#  - location:
#  - title: América se ríe con el logo 'sexual' de Donald Trump y su vic
#  - summary: Trump elige al gobernador de Indiana, Mike Pence, como vicep
#  - author: RODRIGO TERRASA
# Article #4
#  - url: http://www.elmundo.es/internacional/2016/07/16/578994dbe5fdea1a788b45fd.html
#  - datetime: 16/07/2016 05:58
#  - content: Mientras el gobierno turco anunciaba que el fracaso del golp
#  - location: Estambul
#  - title: Erdogan: "Los seguidores del imán Fethullah Gülen pagarán un
#  - summary: Las imágenes y vídeos del golpe de Estado en Turquía. Obama
#  - author: LLUIS MIQUEL HURTADO
# Article #5
#  - url: http://www.elmundo.es/internacional/2016/07/15/57889ec6e2704e59178b4597.html
#  - datetime: 15/07/2016 13:01
#  - content: Al menos 84 personas han muerto después de que un hombre emb
#  - location:
#  - title: Gráfico: Así ha sido el atentado de Niza
#  - summary:
#  - author:
# Article #6
#  - url: http://www.elmundo.es/internacional/2016/07/16/578932ba268e3ed26b8b46aa.html
#  - datetime: 16/07/2016 03:01
#  - content: Del embrión de un stado, anunciado a los cuatro vientos, al
#  - location: El Cairo
#  - title: El Estado Islámico cambia de estrategia ante sus derrotas
#  - summary: Los yihadistas preparan a sus seguidores para la agonía del
#  - author: FRANCISCO CARRIÓN
# Article #7
#  - url: http://www.elmundo.es/internacional/2016/07/13/57862ab146163fe97a8b4645.html
#  - datetime: 13/07/2016 14:23
#  - content: La Comisión Europea ha propuesto este miércoles poner en com
#  - location: Bruselas
#  - title: La UE propone poner en común las normas de asilo para los re
#  - summary: El derecho a un permiso de residencia de larga duración a lo
#  - author: REUTERS
# Article #8
#  - url: http://www.elmundo.es/internacional/2016/07/13/578649f422601d2e4c8b45a0.html
#  - datetime: 13/07/2016 16:57
#  - content: Donald Trump anunció en abril de este año su plan para que M
#  - location: Madrid
#  - title: La 'burla' al muro de Trump contra los inmigrantes
#  - summary: Ha sido erigido por dos artistas estadounidenses para simbol
#  - author: EL MUNDO
# Article #9
#  - url: http://www.elmundo.es/internacional/2016/07/15/57889f8746163f54368b45b3.html
#  - datetime: 15/07/2016 11:28
#  - content: Faltaban unos minutos para las 23.00 horas de la noche cuand
#  - location:
#  - title: Atentado en Niza: ¿Cómo pudo un hombre con un camión atacar
#  - summary: Al menos 84 muertos en un ataque terrorista con un camión. L
#  - author: EL MUNDO
# Article #10
#  - url: http://www.elmundo.es/internacional/2016/07/15/5788a7e4e2704e6b588b45ac.html
#  - datetime: 15/07/2016 11:55
#  - content: El uso de un vehículo para realizar ataques terroristas es u
#  - location: Jerusalén
#  - title: Israel instala obstáculos en sus calles para evitar atentado
#  - summary: El grupo islamista Hamas alienta a los suyos a atropellar a
#  - author: SAL EMERGUI
# Article #11
#  - url: http://www.elmundo.es/internacional/2016/07/15/5787e64b46163f97198b4646.html
#  - datetime: 15/07/2016 02:42
#  - content: En la crisis política, económica y social que atraviesa Vene
#  - location: Caracas
#  - title: Nicolás Maduro cierra filas con sus soldados leales
#  - summary: "Con Padrino controlando la distribución de alimentos, tiene
#  - author: ÁLEX VASQUEZ
# Article #12
#  - url: http://www.elmundo.es/internacional/2016/07/15/57882a94268e3ed16b8b45cb.html
#  - datetime: 15/07/2016 20:02
#  - content: El presidente de Estados Unidos, Barack Obama, ha condenado
#  - location: Washington (EEUU)
#  - title: La Casa Blanca ofrece "el más fuerte apoyo" a Francia
#  - summary: Trump suspende el anuncio sobre su candidato a vicepresident
#  - author: AGENCIAS
# Article #13
#  - url: http://www.elmundo.es/internacional/2016/07/14/57875f21e5fdea58738b459c.html
#  - datetime: 14/07/2016 12:06
#  - content: Hace tiempo que Zimbabue no vivía una situación de inestabil
#  - location: Johannesburgo
#  - title: Un religioso hace tambalear al Gobierno de Robert Mugabe
#  - summary: El pastor Evan Mawarire es la cara visible de las protestas
#  - author: CAROLINA VALDEHÍTA
# Article #14
#  - url: http://www.elmundo.es/internacional/2016/07/14/57865df622601dc5078b4634.html
#  - datetime: 14/07/2016 03:14
#  - content: Al menos 12 personas han muerto y otras 40 han resultado her
#  - location: Amán (Jordania)
#  - title: Bombas rusas contra refugiados en Jordania
#  - summary: Al menos han muerto 12 personas y 40 han resultado heridas t
#  - author: LAILA M.REY
# Article #15
#  - url: http://www.elmundo.es/internacional/2016/07/13/5786379b46163fe97a8b4653.html
#  - datetime: 13/07/2016 15:08
#  - content: Bernardo Provenzano, el ex jefe de Cosa Nostra, la mafia sic
#  - location: Milán
#  - title: Muere Bernardo Provenzano, el histórico 'capo' de Cosa Nostr
#  - summary: Estuvo 43 años en búsqueda y captura hasta su arresto en 200
#  - author: SORAYA MELGUIZO
# Article #16
#  - url: http://www.elmundo.es/internacional/2016/07/13/57867e2b22601d0c448b4618.html
#  - datetime: 13/07/2016 19:56
#  - content: El museo de Auschwitz ha pedido a los responsables de Pokémo
#  - location: Varsovia
#  - title: Auschwitz dice 'no' a Pokémon Go
#  - summary: El museo del campo de concentración ha pedido a la empresa N
#  - author: AFP
# Article #17
#  - url: http://www.elmundo.es/internacional/2016/07/15/57887fcb468aebc1318b466e.html
#  - datetime: 15/07/2016 13:48
#  - content: El 14 de julio, día de celebración nacional en Francia, se t
#  - location: Madrid
#  - title: Las imágenes y los vídeos del atentado en Niza
#  - summary: La policía halla un arsenal de armas en el camión. Interior
#  - author: EL MUNDO
# Article #18
#  - url: http://www.elmundo.es/internacional/2016/07/14/57872bf6e2704e9c2b8b456d.html
#  - datetime: 14/07/2016 08:06
#  - content: Los miembros de las nuevas Panteras Negras, grupo que reivin
#  - location: Washington
#  - title: Los Nuevos Panteras Negras irán armados durante la Convenció
#  - summary: EEUU busca curar su herida racial. La foto que ya es el símb
#  - author: EFE
# Article #19
#  - url: http://www.elmundo.es/internacional/2016/07/14/57868781ca4741d3318b461c.html
#  - datetime: 14/07/2016 04:28
#  - content: La mañana de 2006 en la que Bernardo Provenzano, el capo de
#  - location: Milán
#  - title: Messina, el capo que 'humaniza' a Provenzano
#  - summary: El heredero del jefe de Cosa Nostra fallecido ayer vuelve a
#  - author: SORAYA MELGUIZO
# Article #20
#  - url: http://www.elmundo.es/internacional/2016/07/13/5786359be5fdeac9068b45df.html
#  - datetime: 13/07/2016 14:52
#  - content: El Gobierno alemán ha aprobado este miércoles unas nuevas ba
#  - location: Berlín
#  - title: Alemania abre las filas de sus Fuerzas Armadas a los nacidos
#  - summary: El Gobierno alemán aprueba un 'libro blanco' de Defensa que
#  - author: CARMEN VALERO
# Article #21
#  - url: http://www.elmundo.es/internacional/2016/07/15/578823f9268e3eca6b8b45ce.html
#  - datetime: 15/07/2016 20:14
#  - content: La policía francesa ya ha identificado al autor del ataque t
#  - location: Rabat
#  - title: Un atentado con tintes yihadistas cometido por un delincuent
#  - summary: Conocido por la policía en relación con la delincuencia comú
#  - author: ISAAC J. MARTÍN
# Article #22
#  - url: http://www.elmundo.es/internacional/2016/07/14/5787adf1ca4741b7718b4592.html
#  - datetime: 14/07/2016 18:03
#  - content: El FBI ha detenido a cuatro personas durante el último mes,
#  - location: Washington
#  - title: El FBI arresta a cuatro personas del IS que planeaban atenta
#  - summary: El director del Centro Nacional de Contraterrorismo ha señal
#  - author: REUTERS
# Article #23
#  - url: http://www.elmundo.es/internacional/2016/07/15/5787d44b46163f2a358b4601.html
#  - datetime: 15/07/2016 02:36
#  - content: La diplomacia europea ha disparado a discreción contra el nu
#  - location: Londres
#  - title: La diplomacia europea dispara contra Boris Johnson
#  - summary: "Habría preferido negociar con un socio claro, creíble y fia
#  - author: CARLOS FRESNEDA
# Article #24
#  - url: http://www.elmundo.es/internacional/2016/07/14/5787a40846163f38758b464f.html
#  - datetime: 14/07/2016 16:45
#  - content: El día después de que varios medios japoneses anunciaran que
#  - location: Hong Kong
#  - title: El Palacio Imperial japonés niega que el emperador vaya a ab
#  - summary: La información ha sido desmentida por funcionarios de palaci
#  - author: ISMAEL ARANA
# Article #25
#  - url: http://www.elmundo.es/internacional/2016/07/16/5789e5b546163f54368b464b.html
#  - datetime: 16/07/2016 11:54
#  - content: "Teníamos que rezar por los nuestros, llamarlos a la calle",
#  - location: Estambul
#  - title: La 'llamada' de las mezquitas turcas para apoyar a Erdogan
#  - summary: Al menos 90 muertos en el intento de golpe de Estado en Turq
#  - author: LLUÍS MIQUEL HURTADO
# Article #26
#  - url: http://www.elmundo.es/internacional/2016/07/13/578664e1ca474124288b45fc.html
#  - datetime: 13/07/2016 18:53
#  - content: La paz con las FARC puede estar cerca pero entre Álvaro Urib
#  - location: Bogotá
#  - title: Paz con las FARC y guerra con Uribe
#  - summary: El presidente agitó una bandera blanca y en la orilla contra
#  - author: SALUD HERNÁNDEZ MORA
# Article #27
#  - url: http://www.elmundo.es/internacional/2016/07/13/5786756546163fd5588b4573.html
#  - datetime: 13/07/2016 19:09
#  - content: Diez presos, cinco considerados muy peligrosos, se fugaron l
#  - location: Ciudad de México
#  - title: Fuga de película en la cárcel de Cancún
#  - summary:
#  - author: JAVIER BRANDOLI
# Article #28
#  - url: http://www.elmundo.es/internacional/2016/07/14/5787e1bf468aeb12138b46a1.html
#  - datetime: 14/07/2016 21:16
#  - content: EEUU quiere crear con Rusia un nuevo centro para coordinar l
#  - location: Moscú
#  - title: Estados Unidos propone coordinar con Rusia los ataques en Si
#  - summary: Moscú ve insuficiente el impulso conjunto en Siria. Kerry di
#  - author: XAVIER COLÁS
# Article #29
#  - url: http://www.elmundo.es/internacional/2016/07/15/57891024268e3ee26b8b4680.html
#  - datetime: 15/07/2016 18:37
#  - content: Gracias a Facebook, una familia logró encontrar anoche en Ni
#  - location: París
#  - title: Una familia encuentra a su bebé tras el atentado gracias a F
#  - summary:
#  - author: EFE
# Article #30
#  - url: http://www.elmundo.es/internacional/2016/07/16/5789ed2246163f43018b45d9.html
#  - datetime: 16/07/2016 10:39
#  - content: El autodenominado Estado Islámico ha reivindicado ese sábado
#  - location: NizaEl Cairo
#  - title: El Estado Islámico reivindica el atentado de Niza
#  - summary: Al menos 84 muertos y cientos de heridos en un ataque terror
#  - author: IRENE HDEZ. VELASCOFRANCISCO CARRIÓN
# Article #31
#  - url: http://www.elmundo.es/internacional/2016/07/14/57880490e2704ebe158b4641.html
#  - datetime: 15/07/2016 13:08
#  - content: El terror ha vuelto a conmocionar Francia. Al menos 84 perso
#  - location: París | MadridParís | Niza
#  - title: Atentado en Niza: al menos 84 muertos y 50 heridos críticos
#  - summary: Un ataque con la firma del Estado Islámico. ÁLBUM: El atenta
#  - author: MARÍA D. VALDERRAMA | MARÍA HERNÁNDEZAGENCIAS
# Article #32
#  - url: http://www.elmundo.es/internacional/2016/07/15/5788c428e2704e32738b4612.html
#  - datetime: 15/07/2016 13:49
#  - content: La operación policial contra el autor del atentado de Niza q
#  - location:
#  - title: El héroe que asaltó la cabina y ayudó a neutralizar al condu
#  - summary: El camión acabó con al menos medio centenar de impactos de b
#  - author: EL MUNDO
# Article #33
#  - url: http://www.elmundo.es/internacional/2016/07/13/57863b14e2704ee3418b45f3.html
#  - datetime: 13/07/2016 14:59
#  - content: El emperador de Japón, Akihito, ha anunciado a los 82 años s
#  - location: Hong Kong
#  - title: El emperador de Japón Akihito abdicará en favor de su hijo
#  - summary: El estado de salud del emperador es la principal causa de su
#  - author: Ismael Arana
# Article #34
#  - url: http://www.elmundo.es/internacional/2016/07/14/5787763de5fdea1f198b4616.html
#  - datetime: 14/07/2016 13:29
#  - content: El jefe de la estación de ferrocarril de Andria, en el sur d
#  - location: Roma
#  - title: El jefe de estación admite que dio vía libre a uno de los tr
#  - summary: "La señal la levanté yo, no sabía que desde Corato estuviese
#  - author: EFE
# Article #35
#  - url: http://www.elmundo.es/internacional/2016/07/13/5786500b46163f45198b45cd.html
#  - datetime: 13/07/2016 17:51
#  - content: Al menos 31 civiles, entre ellos varios niños, han muerto es
#  - location: Beirut
#  - title: Al menos 31 muertos en Siria por bombardeos a las ciudades r
#  - summary: Los ataque se producen en medio de una tregua decretada hast
#  - author: FRANCE PRESSE
# Article #36
#  - url: http://www.elmundo.es/internacional/2016/07/13/57863b3ce5fdea8e2a8b45c8.html
#  - datetime: 13/07/2016 16:14
#  - content: Han bastado casi cuatro meses para que Marruecos ceda a la p
#  - location: Rabat
#  - title: La ONU acuerda con Marruecos el regreso de 25 miembros de la
#  - summary: El personal civil irá regresando gradualmente y se espera qu
#  - author: ISAAC J. MARTÍN
# Article #37
#  - url: http://www.elmundo.es/internacional/2016/07/16/5789fba1468aebba388b4620.html
#  - datetime: 16/07/2016 11:29
#  - content: La tradición golpista del ejército turco tiene una alargada
#  - location:
#  - title: La alargada sombra del 'guardián del laicismo'
#  - summary:
#  - author: ROSA MENESES
# Article #38
#  - url: http://www.elmundo.es/internacional/2016/07/13/57865636268e3e43418b4651.html
#  - datetime: 13/07/2016 17:01
#  - content: Dos aviones han colisionado este miércoles en la pista del A
#  - location: Madrid
#  - title: Dos aviones colisionan en la pista del aeropuerto de Minsk
#  - summary: No hay pasajeros ni trabajadores afectados. Una fuerte torme
#  - author: EL MUNDO
# Article #39
#  - url: http://www.elmundo.es/internacional/2016/07/15/5788f55846163f947c8b457e.html
#  - datetime: 15/07/2016 17:18
#  - content: El fiscal general francés, François Molins, ha confirmado qu
#  - location:
#  - title: Atentado en Niza: El fiscal confirma la muerte de 84 persona
#  - summary: Francia no tiene fichado al autor del atentado como un yihad
#  - author: EL MUNDO
# Article #40
#  - url: http://www.elmundo.es/internacional/2016/07/15/578903dee2704e17078b4641.html
#  - datetime: 15/07/2016 18:41
#  - content: Niza es el hogar de 342.295 personas, según datos del INSEE
#  - location:
#  - title: Niza, 31 ataques terroristas en 40 años
#  - summary: Es la segunda ciudad francesa con más hoteles, después de Pa
#  - author: PAULA GUISADONALINI LEPETIT
# Article #41
#  - url: http://www.elmundo.es/internacional/2016/07/16/5789dd23468aeb592b8b4641.html
#  - datetime: 16/07/2016 09:11
#  - content: Revelar algo un viernes por la tarde en el mes de julio es l
#  - location: Washington
#  - title: EEUU acusa a miembros de los servicios de inteligencia saudí
#  - summary: El Gobierno desvela parte del informe oficial de la Comisión
#  - author: PABLO PARDO
# Article #42
#  - url: http://www.elmundo.es/internacional/2016/07/16/57890b5122601d865d8b45f8.html
#  - datetime: 16/07/2016 12:23
#  - content: ¿Es Francia objetivo prioritario del terrorismo islamista en
#  - location:
#  - title: Francia, objetivo prioritario
#  - summary: Que se hayan repetido los atentados en suelo galo se debe a
#  - author: FELIPE SAHAGÚN
# Article #43
#  - url: http://www.elmundo.es/internacional/2016/07/14/5787428d46163f72208b459d.html
#  - datetime: 14/07/2016 09:43
#  - content: Al menos ocho personas, entre ellas cuatro niños, han muerto
#  - location: Nairobi
#  - title: Al menos 8 muertos, 4 de ellos niños, en el incendio de un o
#  - summary: De momento se desconocen las causas del incendio
#  - author: EFE
# Article #44
#  - url: http://www.elmundo.es/internacional/2016/07/15/57881a72268e3ed06b8b45c6.html
#  - datetime: 15/07/2016 01:12
#  - content: El presidente del Gobierno, Mariano Rajoy, y el líder del PS
#  - location: Madrid
#  - title: El Rey y todos los políticos españoles, "consternados" con e
#  - summary: Mariano Rajoy ofrece toda la cooperación para erradicar la "
#  - author: AGENCIAS
# Article #45
#  - url: http://www.elmundo.es/internacional/2016/07/15/5788d76f468aeb93178b45da.html
#  - datetime: 15/07/2016 20:43
#  - content: Entre las 84 víctimas del atentado de Niza hay 10 niños y ad
#  - location:
#  - title: Las víctimas del atentado de Niza
#  - summary: Al menos 84 muertos en un ataque terrorista con un camión. I
#  - author: EL MUNDO
# Article #46
#  - url: http://www.elmundo.es/internacional/2016/07/13/5786829046163fef4a8b456c.html
#  - datetime: 13/07/2016 20:04
#  - content: "¿En la cúpula militar no conocen la existencia de Google?",
#  - location: Jerusalén
#  - title: Rabino militar israelí rectifica sus comentarios homófobos d
#  - summary:
#  - author: SAL EMERGUI
# Article #47
#  - url: http://www.elmundo.es/internacional/2016/07/16/578912c922601df5248b4689.html
#  - datetime: 16/07/2016 03:02
#  - content: El brutal atentado cometido en Niza la noche del viernes 14
#  - location:
#  - title: Atentados 'low cost', pero de alto rendimiento
#  - summary: No es necesario que el ataque haya sido perfectamente conceb
#  - author: PEDRO BAÑOS
# Article #48
#  - url: http://www.elmundo.es/internacional/2016/07/13/5786280fca4741a3508b4637.html
#  - datetime: 13/07/2016 14:00
#  - content: Israel, en un nuevo intento de dañar a su máximo archienemig
#  - location: Teherán
#  - title: Irán acusa a Israel de destruir su caviar en el Mar Caspio
#  - summary: Teherán asegura que Tel Aviv es responsable de la presencia
#  - author: ZAHIDA MEMBRADO
# Article #49
#  - url: http://www.elmundo.es/internacional/2016/07/15/5788defa46163f617e8b457d.html
#  - datetime: 16/07/2016 10:18
#  - content: Niza fue durante muchos años la capital de la Belle Époque.
#  - location:
#  - title: Niza, un nido yihadista en Francia
#  - summary: Al menos 84 muertos en un ataque terrorista con un camión. E
#  - author: AFP
# Article #50
#  - url: http://www.elmundo.es/internacional/2016/07/15/5788d88ae2704e14198b4612.html
#  - datetime: 15/07/2016 19:02
#  - content: El primer pulso político entre la 'premier' ,Theresa May, y
#  - location: Londres
#  - title: Nicola Sturgeon: "Escocia no es lo mismo que Cataluña"
#  - summary: Nicola Sturgeon ha dejado claro que el referéndum de indepen
#  - author: CARLOS FRESNEDA
# Article #51
#  - url: http://www.elmundo.es/internacional/2016/07/13/578682bd22601df07b8b45d9.html
#  - datetime: 13/07/2016 20:34
#  - content: Quince minutos y 600 dólares. Es lo que le costó al autor de
#  - location: Nueva York
#  - title: El autor de la masacre de Dallas compró un AK-47 en Facebook
#  - summary: El vendedor del arma, Colton Crews, asegura que Micah Xavier
#  - author: CAROLINA MARTÍN
# Article #52
#  - url: http://www.elmundo.es/internacional/2016/07/14/57873a44e5fdeac82e8b45bc.html
#  - datetime: 14/07/2016 10:01
#  - content: Las familias de presos ejecutados y desaparecidos en Colonia
#  - location: Santiago de Chile
#  - title: Las familias de las víctimas piden a Alemania el cierre al t
#  - summary: En este enclave al sur de Santiago militares chilenos y colo
#  - author: EFE
# Article #53
#  - url: http://www.elmundo.es/internacional/2016/07/15/578817d1268e3ec66b8b45d3.html
#  - datetime: 15/07/2016 07:07
#  - content: El IS ha llamado en reiteradas ocasiones a sus seguidores a
#  - location: El Cairo
#  - title: Atentado en Niza: un ataque con la firma del Estado Islámico
#  - summary: Al menos 73 muertos en Niza tras un ataque terrorista perpet
#  - author: FRANCISCO CARRIÓN
# Article #54
#  - url: http://www.elmundo.es/internacional/2016/07/15/578940e3268e3e1b0b8b45fb.html
#  - datetime: 16/07/2016 12:08
#  - content: El Servicio de Inteligencia de Turquía ha dado este sábado p
#  - location: Estambul
#  - title: El sangriento intento de golpe de Estado en Turquía deja 265
#  - summary: ÁLBUM: Las imágenes del golpe de Estado. Erdogan llama a los
#  - author: LLUIS MIQUEL HURTADO
# Article #55
#  - url: http://www.elmundo.es/internacional/2016/07/14/5786c4ef22601d986b8b4570.html
#  - datetime: 14/07/2016 00:47
#  - content: El dirigente opositor venezolano Henrique Capriles consideró
#  - location: Caracas
#  - title: Capriles dice que Rodríguez Zapatero "falla" en su diagnósti
#  - summary: Sugirió que Zapatero no está en Venezuela para "buscar una s
#  - author: EFE
# Article #56
#  - url: http://www.elmundo.es/internacional/2016/07/14/578714cf46163fee638b459f.html
#  - datetime: 14/07/2016 06:28
#  - content: Después de una sesión de más de siete horas que se cerró bie
#  - location: Río de Janeiro
#  - title: Rodrigo Maia ocupará el lugar de Cunha en la presidencia de
#  - summary:
#  - author: GERMÁN ARANDA

# %% [markdown]
# # Conclusión
# Espero que este cuaderno te haya sido útil y que te haya ayudado el hecho de poder interactuar con el código al tiempo que lees el texto de las explicaciones. Y también que hayas sido consciente del poder de las expresiones regulares (regex) junto con el xpath para las labores de scraping.
